# %%
https://github.com/lux-org/lux?tab=readme-ov-file
# Out:
#   File "<ipython-input-1-8140ef6275fe>", line 1
#     https://github.com/lux-org/lux?tab=readme-ov-file
#           ^
# SyntaxError: invalid syntax
