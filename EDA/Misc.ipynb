# %%
import pandas as pd

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_India", match="Historical Population of India")
df = pd.DataFrame(html[0])
df
# Out:
#                           Era       Year  Estimated Population Growth Rate (%)
# 0                 Prehistoric  10,000 BC               1023542             NaN
# 1                 Prehistoric    5000 BC               5231678         +411.2%
# 2                   Neolithic    4000 BC               7003245          +33.9%
# 3                   Neolithic    3000 BC               9875620          +41.0%
# 4   Indus Valley Civilization    2000 BC              13642189          +38.2%
# 5   Indus Valley Civilization    1500 BC              15246830          +11.8%
# 6                Vedic Period    1000 BC              16895450          +10.8%
# 7                Vedic Period     500 BC              22783692          +34.9%
# 8               Maurya Empire     250 BC              40684927          +78.6%
# 9               Maurya Empire       1 AD              51287345          +26.1%
# 10            Classical India     100 AD              52748932           +2.8%
# ...

# %%
type(df)
# Out:
# list
